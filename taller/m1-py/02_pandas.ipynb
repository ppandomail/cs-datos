# %% [markdown]
# # Pandas

# %% [markdown]
# * PanDaS: Panel Data Sets
# * Biblioteca de Python para trabajar con datos: analizar, limpiar, explorar y manipular los datos
# * Sirve para manipular tablas de datos (DataFrame)
# * Permite analizar grandes datos y sacar conclusiones basadas en teorías estadísticas:
#   * ¿Existe una correlación entre dos o más variables/columnas?
#   * ¿Cual es el valor medio, máximo, mínimo?
#   * Etc.
# * Limpiar datos: eliminar casos/filas irrelevantes o que contienen valores incorrectos (valores vacíos o nulos)

# %% [markdown]
# ## Instalación

# %% [markdown]
# pip install pandas

# %% [markdown]
# ## Series

# %% [markdown]
# * Es un array unidimensional (como una columna de una tabla) que contiene datos de cualquier tipo

# %%
import pandas as pd  # gralmente. se importa con el alias pd

# %%
lista = [1, 7, 2]

# %%
# Serie a partir de una lista con etiquetas por default mediante número de índice
serie = pd.Series(lista)
serie
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
serie[1]
# Out:
# 7

# %%
# Serie a partir de una lista con etiquetas definidas
serie = pd.Series(lista, index = ["x", "y", "z"])
serie
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %%
serie['y']
# Out:
# 7

# %%
# Serie a partir de un diccionario (las claves del diccionario se convierten en las etiquetas)
calorias = {'dia1': 420, 'dia2': 380, 'dia3': 390}
serie = pd.Series(calorias)
serie
# Out:
# dia1    420
# dia2    380
# dia3    390
# dtype: int64

# %%
serie['dia2']
# Out:
# 380

# %%
# Serie a partir de un diccionario especificando claves
serie = pd.Series(calorias, index = ['dia1', 'dia2'])
serie
# Out:
# dia1    420
# dia2    380
# dtype: int64

# %% [markdown]
# ## Dataframes

# %% [markdown]
# * Es un array bidimensional (la tabla completa)

# %%
# crear dataframe vacio
df = pd.DataFrame(columns=['Nombre', 'Edad'])
df
# Out:
# Empty DataFrame
# Columns: [Nombre, Edad]
# Index: []

# %%
df.loc[0]  = {'Nombre': 'Pablo', 'Edad': 38}
df
# Out:
#   Nombre  Edad
# 0  Pablo    38

# %%
fbk = ['Facebook', 2449, True, 2006]
twt = ['Twitter', 339, False, 2006]
igm = ['Instagram', 1000, True, 2010]
ytb = ['YouTube', 2000, False, 2005]
lkn = ['LinkedIn', 663, False, 2003]
wsp = ['WhastsApp', 1600, True, 2009]

rrss = [fbk, twt, igm, ytb, lkn, wsp]

# crear dataframe a partir de una lista
df = pd.DataFrame(rrss, columns=['Nombre', 'Cantidad', 'es_FBK', 'Año'])
df
# Out:
#       Nombre  Cantidad  es_FBK   Año
# 0   Facebook      2449    True  2006
# 1    Twitter       339   False  2006
# 2  Instagram      1000    True  2010
# 3    YouTube      2000   False  2005
# 4   LinkedIn       663   False  2003
# 5  WhastsApp      1600    True  2009

# %%
datos = {
  "calorias": [420, 380, 390],
  "duracion": [50, 40, 45]
}

# crar dataframe a partir de un diccionario con etiquetas por default mediante número de índice
df = pd.DataFrame(datos)
df
# Out:
#    calorias  duracion
# 0       420        50
# 1       380        40
# 2       390        45

# %%
# seleccionar un elemento por etiqueta
df.loc[0, 'calorias']
# Out:
# 420

# %%
# seleccionar un elemento por número
df.iloc[0, 0]
# Out:
# 420

# %%
# seleccionar por columna
df['calorias']
# Out:
# 0    420
# 1    380
# 2    390
# Name: calorias, dtype: int64

# %%
# seleccionar por fila
df.iloc[0]
# Out:
# calorias    420
# duracion     50
# Name: 0, dtype: int64

# %%
# seleccionar dos filas
df.iloc[[0, 1]]
# Out:
#    calorias  duracion
# 0       420        50
# 1       380        40

# %%
# seleccionar por condición booleana
df[df['calorias'] > 385]
# Out:
#    calorias  duracion
# 0       420        50
# 2       390        45

# %%
# ordenar columna ascendente
df.sort_values('calorias', ascending=True)
# Out:
#    calorias  duracion
# 1       380        40
# 2       390        45
# 0       420        50

# %%
# ordenar columna descendente
df.sort_values('calorias', ascending=False)
# Out:
#    calorias  duracion
# 0       420        50
# 2       390        45
# 1       380        40

# %%
# ordenar columnas por dos valores
df.sort_values(['calorias', 'duracion'], ascending=[True, False])
# Out:
#    calorias  duracion
# 1       380        40
# 2       390        45
# 0       420        50

# %%
# Dataframe a partir de un diccionario con etiquetas definidas
df = pd.DataFrame(datos, index = ["dia1", "dia2", "dia3"])
df
# Out:
#       calorias  duracion
# dia1       420        50
# dia2       380        40
# dia3       390        45

# %%
# seleccionar fila por etiqueta definida
df.loc['dia2']
# Out:
# calorias    380
# duracion     40
# Name: dia2, dtype: int64

# %%
# Dataframe a partir de un archivo csv (archivos separadas por comas). Importar
df = pd.read_csv('data/pandas_datos.csv', sep=',')
df # invoca al método __str__ (mostrando por default las primeras 5 filas y las últimas 5 filas)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.5
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
# Dataframe a partir de un archivo json (texto simple con formato de un objeto, 
# mismo formato que los diccionarios de Python)
df = pd.read_json('data/pandas_datos.json')

# %% [markdown]
# ## Analyzing

# %%
df = pd.read_csv('data/pandas_datos.csv')

# %%
df.shape      # dimensiones (filas, columnas)
# Out:
# (169, 4)

# %%
df.size       # número de elementos: filas x columnas
# Out:
# 676

# %%
df.columns    # nombres de columnas
# Out:
# Index(['Duration', 'Pulse', 'Maxpulse', 'Calories'], dtype='object')

# %%
df.index      # nombres de filas
# Out:
# RangeIndex(start=0, stop=169, step=1)

# %%
df.dtypes     # tipos de datos
# Out:
# Duration      int64
# Pulse         int64
# Maxpulse      int64
# Calories    float64
# dtype: object

# %%
df.head()     # visualización de las primeras 5 filas (default)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
df.head(10)    # visualización de las primeras 10 filas
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0
# 5        60    102       127     300.5
# 6        60    110       136     374.0
# 7        45    104       134     253.3
# 8        30    109       133     195.1
# 9        60     98       124     269.0

# %%
df.tail()      # visualización de las últimas 5 filas (default)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 164        60    105       140     290.8
# 165        60    110       145     300.4
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
df.tail(10)    # visualización de las últimas 10 filas
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 159        30     80       120     240.9
# 160        30     85       120     250.4
# 161        45     90       130     260.4
# 162        45     95       130     270.0
# 163        45    100       140     280.9
# 164        60    105       140     290.8
# 165        60    110       145     300.4
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
df_filtrado = df[df['Duration'] > 120]
df_filtrado
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 60        210    108       160    1376.0
# 61        160    110       137    1034.4
# 62        160    109       135     853.0
# 65        180     90       130     800.4
# 66        150    105       135     873.4
# 67        150    107       130     816.0
# 69        300    108       143    1500.2
# 70        150     97       129    1115.0
# 73        150     97       127     953.2
# 79        270    100       131    1729.0
# 90        180    101       127     600.1
# 106       180     90       120     800.3
# 109       210    137       184    1860.4

# %%
df_filtrado = df[(df['Duration'] > 200) & (df['Pulse'] > 100)]
df_filtrado
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 60        210    108       160    1376.0
# 69        300    108       143    1500.2
# 109       210    137       184    1860.4

# %%
df.info()      # información sobre el conjunto de los datos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB

# %%
df.describe()   # muestra estadísticas de las columnas numéricas
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   164.000000
# mean    63.846154  107.461538  134.047337   375.800000
# std     42.299949   14.510259   16.450434   266.377134
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000

# %% [markdown]
# * **corr()**: muestra la relación entre las columnas, ignorando las columnas "no numéricas"
# * Es una tabla con muchos números que representan qué tan buena es la relación entre dos columnas
# * El número varía de -1 a 1
#     * **1** : correlación perfecta (cada vez que un valor aumenta, el otro también)
#     * **0.9** : buena relación    (si aumenta un valor, el otro probablemente también aumentará)
#     * **-0.9** : buena relación    (si aumenta un valor, el otro probablement disminuirá)
#     * **0.2** : NO buena relación (si aumenta un valor, no significa que el otro lo hará)

# %%
df.corr()
# Out:
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.155408  0.009403  0.922721
# Pulse    -0.155408  1.000000  0.786535  0.025120
# Maxpulse  0.009403  0.786535  1.000000  0.203814
# Calories  0.922721  0.025120  0.203814  1.000000

# %% [markdown]
# * Análisis:
#     * **Duration y Duration**: Perfecta, cada columna siempre tiene una relación perfecta consigo misma
#     * **Duration y Calories**: Muy Buena, podemos predecir que cuanto mas entrenes, mas calorias quemarás
#     * **Duration y Pulse**: Muy Mala, no podemos predecir el pulso máximo simplemente mirando la duración del entrenamiento

# %% [markdown]
# ## Cleaning

# %% [markdown]
# * La limpieza de datos significa corregir datos erróneos:
#
# | Tipo                   | id | Duration | Date    | Pulse| Maxpulse | Calories | Observaciones     |
# | --                     | -- | --  | --           | --  | --  | --    | --                         |
# | **Celdas vacias**      | 18 | 45  | '18/12/2020' | 90  | 112 | NaN   | también en la fila 22 y 28 |
# | **Formato incorrecto** | 26 | 60  | 2020/12/26   | 100 | 120 | 250.0 | date en otro formato       |
# | **Datos erróneos**     |  7 | 450 | '2020/12/08' | 104 | 134 | 253.3 | 30 <= duración <= 60       |
# | **Duplicados**         | 11 | 60  | '12/12/2020' | 100 | 120 | 250.7 |                            |
# |                        | 12 | 60  | '12/12/2020' | 100 | 120 | 250.7 |                            |

# %%
df = pd.read_csv('data/pandas_datos2.csv')
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %% [markdown]
# ### Celdas vacias

# %% [markdown]
# #### Estrategia 1: Elimina celdas vacias (con valores NULL)

# %%
df = pd.read_csv('data/pandas_datos2.csv')
df = df.dropna()
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %% [markdown]
# #### Estrategia 2: Reemplaza celdas vacias con un valor

# %%
df = pd.read_csv('data/pandas_datos2.csv')
df = df.fillna(130)
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %% [markdown]
# #### Estrategia 3: Reemplaza celdas vacias de una columna

# %%
df = pd.read_csv('data/pandas_datos2.csv')
df = df.fillna({"Calories": 130})
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %% [markdown]
# #### Estrategia 4: Reemplaza celdas vacias con el valor de la media (promedio)

# %%
df = pd.read_csv('data/pandas_datos2.csv')
media = df['Calories'].mean()
df = df.fillna({"Calories": media}) 
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130    409.10
# 1         60  '2020/12/02'    117       145    479.00
# 2         60  '2020/12/03'    103       135    340.00
# 3         45  '2020/12/04'    109       175    282.40
# 4         45  '2020/12/05'    117       148    406.00
# 5         60  '2020/12/06'    102       127    300.00
# 6         60  '2020/12/07'    110       136    374.00
# 7        450  '2020/12/08'    104       134    253.30
# 8         30  '2020/12/09'    109       133    195.10
# 9         60  '2020/12/10'     98       124    269.00
# 10        60  '2020/12/11'    103       147    329.30
# 11        60  '2020/12/12'    100       120    250.70
# 12        60  '2020/12/12'    100       120    250.70
# 13        60  '2020/12/13'    106       128    345.30
# 14        60  '2020/12/14'    104       132    379.30
# 15        60  '2020/12/15'     98       123    275.00
# ...

# %% [markdown]
# #### Estrategia 5: Reemplaza celdas vacias con el valor de la mediana (valor medio, después de orden ascendente)

# %%
df = pd.read_csv('data/pandas_datos2.csv')
mediana = df['Calories'].median()
df = df.fillna({"Calories": mediana}) 
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %% [markdown]
# #### Estrategia 6: Reemplaza celdas vacias con el valor de la moda (valor que aparece con mayor frecuencia)

# %%
df = pd.read_csv('data/pandas_datos2.csv')
moda = df['Calories'].mode()[0]
df = df.fillna({"Calories": moda}) 
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %% [markdown]
# ### Formato incorrecto

# %%
# Convertir todas las celdas de las columnas al mismo formato (por ej. fecha)
df = pd.read_csv('data/pandas_datos2.csv')
df['Date'] = pd.to_datetime(df['Date'], format = 'mixed')                  
df
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7        450 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# ...

# %%
# La fecha vacía de la fila 22 obtuvo un valor NaT (No es una hora); es decir, un valor vacío 
# Una forma de solucionar los valores vacíos es simplemente eliminar toda la fila
df = df.dropna(subset=['Date'])
df
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7        450 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# ...

# %% [markdown]
# ### Datos erróneos

# %% [markdown]
# #### Estrategia 1: Reemplazar por otro valor, cuando son pocos los datos erróneos. En el ejemplo seguro fue un error tipográfico y el valor debería ser "45" en lugar de "450"

# %%
df = pd.read_csv('data/pandas_datos2.csv')
df.loc[7, 'Duration'] = 45               
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7         45  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %% [markdown]
# #### Estrategia 2: Reemplazar por otro valor mediante reglas, cuando son muchos los datos erróneos

# %%
df = pd.read_csv('data/pandas_datos2.csv')
for i in df.index:
    if df.loc[i, 'Duration'] > 120:
        df.loc[i, 'Duration'] = 120
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        120  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %% [markdown]
# #### Estrategia 3: Eliminar filas que contienen datos erróneos

# %%
df = pd.read_csv('data/pandas_datos2.csv')
for i in df.index:
  if df.loc[i, "Duration"] > 120:
    df = df.drop(i)
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# 16        60  '2020/12/16'     98       120     215.2
# ...

# %% [markdown]
# ### Duplicados

# %%
df = pd.read_csv('data/pandas_datos2.csv')
dfdupl = df.duplicated()   # devuelve un bool para cada fila (True para cada fila que sea un duplicado)
dfdupl
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# dtype: bool

# %%
df = df.drop_duplicates()
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# 16        60  '2020/12/16'     98       120     215.2
# ...

# %% [markdown]
# ## Export

# %%
fbk = ['Facebook', 2449, True, 2006]
twt = ['Twitter', 339, False, 2006]
igm = ['Instagram', 1000, True, 2010]
ytb = ['YouTube', 2000, False, 2005]
lkn = ['LinkedIn', 663, False, 2003]
wsp = ['WhastsApp', 1600, True, 2009]

rrss = [fbk, twt, igm, ytb, lkn, wsp]

df = pd.DataFrame(rrss, columns=['Nombre', 'Cantidad', 'es_FBK', 'Anio'])
df
# Out:
#       Nombre  Cantidad  es_FBK  Anio
# 0   Facebook      2449    True  2006
# 1    Twitter       339   False  2006
# 2  Instagram      1000    True  2010
# 3    YouTube      2000   False  2005
# 4   LinkedIn       663   False  2003
# 5  WhastsApp      1600    True  2009

# %% [markdown]
# ### Exportar a Excel

# %%
# Exportar df a excel
df.to_excel('data/pandas_datos_export.xlsx')

# %%
# Exportar df a excel sin indices 
df.to_excel('data/pandas_datos_export_no_index.xlsx', index=False)

# %% [markdown]
# ### Exportar a CSV

# %%
# Exportar df a csv
df.to_csv('data/pandas_datos_export.csv')

# %%
# Exportar df a csv sin indices
df.to_csv('data/pandas_datos_export_no_index.csv', index=False)

# %%
# Exportar df a csv sin indices y con puntos y coma
df.to_csv('data/pandas_datos_export_no_index_pyc.csv', index=False, sep=';')

# %% [markdown]
# ## Ejemplo: Arbolado en espacios verdes

# %% [markdown]
# ### Lectura de datos

# %%
df = pd.read_csv('data/arbolado-en-espacios-verdes.csv')
df
# Out:
#             long        lat  id_arbol  altura_tot  diametro  inclinacio  \
# 0     -58.477564 -34.645015         1           6        35           0
# 1     -58.477559 -34.645047         2           6        35           0
# 2     -58.477551 -34.645091         3           6        35           0
# 3     -58.478129 -34.644567         4          17        50           0
# 4     -58.478121 -34.644598         5          17        50           0
# ...          ...        ...       ...         ...       ...         ...
# 51497 -58.505752 -34.562998     51725          15        30           0
# 51498 -58.507111 -34.565843     51726          13        31           0
# 51499 -58.475721 -34.565192     51727          11        28           0
# 51500 -58.507026 -34.565670     51728           5        32           0
# 51501 -58.506874 -34.565334     51729          10        35           0
#
#        id_especie                                       nombre_com  \
# ...

# %%
df['altura_tot']
# Out:
# 0         6
# 1         6
# 2         6
# 3        17
# 4        17
#          ..
# 51497    15
# 51498    13
# 51499    11
# 51500     5
# 51501    10
# Name: altura_tot, Length: 51502, dtype: int64

# %%
df.altura_tot
# Out:
# 0         6
# 1         6
# 2         6
# 3        17
# 4        17
#          ..
# 51497    15
# 51498    13
# 51499    11
# 51500     5
# 51501    10
# Name: altura_tot, Length: 51502, dtype: int64

# %% [markdown]
# ### Exploración de datos

# %%
df.head()
# Out:
#         long        lat  id_arbol  altura_tot  diametro  inclinacio  \
# 0 -58.477564 -34.645015         1           6        35           0
# 1 -58.477559 -34.645047         2           6        35           0
# 2 -58.477551 -34.645091         3           6        35           0
# 3 -58.478129 -34.644567         4          17        50           0
# 4 -58.478121 -34.644598         5          17        50           0
#
#    id_especie                           nombre_com             nombre_cie  \
# 0          53  Washingtonia (Palmera washingtonia)  Washingtonia filifera
# 1          53  Washingtonia (Palmera washingtonia)  Washingtonia filifera
# 2          53  Washingtonia (Palmera washingtonia)  Washingtonia filifera
# 3          65                                 Ombú      Phytolacca dioica
# 4          65                                 Ombú      Phytolacca dioica
#
#                       tipo_folla                  espacio_ve  \
# ...

# %%
df.tail()
# Out:
#             long        lat  id_arbol  altura_tot  diametro  inclinacio  \
# 51497 -58.505752 -34.562998     51725          15        30           0
# 51498 -58.507111 -34.565843     51726          13        31           0
# 51499 -58.475721 -34.565192     51727          11        28           0
# 51500 -58.507026 -34.565670     51728           5        32           0
# 51501 -58.506874 -34.565334     51729          10        35           0
#
#        id_especie                                       nombre_com  \
# 51497          45                                        Casuarina
# 51498          45                                        Casuarina
# 51499          17  Árbol del cielo (Ailanto o Árbol de los dioses)
# 51500         342                                           Ciprés
# 51501         342                                           Ciprés
#
#                      nombre_cie                     tipo_folla  \
# ...

# %%
len(df.columns)
# Out:
# 17

# %%
df.index
# Out:
# RangeIndex(start=0, stop=51502, step=1)

# %%
df.shape
# Out:
# (51502, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51502 entries, 0 to 51501
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   long        51502 non-null  float64
#  1   lat         51502 non-null  float64
#  2   id_arbol    51502 non-null  int64
#  3   altura_tot  51502 non-null  int64
#  4   diametro    51502 non-null  int64
#  5   inclinacio  51502 non-null  int64
#  6   id_especie  51502 non-null  int64
#  7   nombre_com  51502 non-null  object
#  8   nombre_cie  51502 non-null  object
#  9   tipo_folla  51502 non-null  object
#  10  espacio_ve  51502 non-null  object
#  11  ubicacion   50529 non-null  object
#  12  nombre_fam  51502 non-null  object
#  13  nombre_gen  51502 non-null  object
#  14  origen      51502 non-null  object
#  15  coord_x     51502 non-null  float64
#  16  coord_y     51502 non-null  float64
# dtypes: float64(4), int64(5), object(8)
# memory usage: 6.7+ MB

# %%
df.describe()
# Out:
#                long           lat      id_arbol    altura_tot      diametro  \
# count  51502.000000  51502.000000  51502.000000  51502.000000  51502.000000
# mean     -58.439558    -34.606839  25866.623296     12.167100     39.395616
# std        0.044614      0.042900  14936.773619      7.640309     31.171205
# min      -58.529743    -34.697716      1.000000      0.000000      1.000000
# 25%      -58.471941    -34.642570  12927.250000      6.000000     18.000000
# 50%      -58.441735    -34.608041  25870.500000     11.000000     32.000000
# 75%      -58.409357    -34.570255  38800.750000     18.000000     54.000000
# max      -58.353746    -34.527167  51729.000000     54.000000    500.000000
#
#          inclinacio    id_especie        coord_x        coord_y
# count  51502.000000  51502.000000   51502.000000   51502.000000
# mean       3.472215    112.769504  102177.845378  102487.232275
# std        7.039495    162.693940    4092.013488    4759.012618
# ...

# %% [markdown]
# ### Selección de datos

# %%
df['nombre_com']
# Out:
# 0                    Washingtonia (Palmera washingtonia)
# 1                    Washingtonia (Palmera washingtonia)
# 2                    Washingtonia (Palmera washingtonia)
# 3                                                   Ombú
# 4                                                   Ombú
#                               ...
# 51497                                          Casuarina
# 51498                                          Casuarina
# 51499    Árbol del cielo (Ailanto o Árbol de los dioses)
# 51500                                             Ciprés
# 51501                                             Ciprés
# Name: nombre_com, Length: 51502, dtype: object

# %%
df['nombre_com'].unique()
# Out:
# array(['Washingtonia (Palmera washingtonia)', 'Ombú', 'Catalpa', 'Ceibo',
#        'Brachichiton (Árbol botella, Brachichito)', 'Álamo plateado',
#        'Acacia de constantinopla', 'Acacia', 'Roble sedoso (Grevillea)',
#        'Arce', 'Palo borracho rosado', 'Álamo negro del Canada',
#        'Jacarandá', 'Álamo carolina', 'Aguaribay', 'Paraíso',
#        'Espinillo (Aromo)', 'Eucalipto', 'Ciprés leylandi', 'Ciprés',
#        'No Determinable', 'Álamo', 'No Determinado', 'Cedro', 'Lapacho',
#        'Crataegus', 'Cedro de San Juan', 'Juniperus', 'Chamaecyparis',
#        'Álamo blanco piramidal', 'Podocarpus', 'Tuja', 'El chañar',
#        'Arce tridente', 'Citricos', 'Sauce', 'Viburnum dulce',
#        'Corona de cristo', 'Taxodium', 'Mirto', 'Árbol del humo',
#        'Celtis tala', 'Criptomeria (Cedro del Japón)', 'Coculus, Cóculo',
#        'Caoba del sur', 'Arce blanco', 'Malus', 'Agatis blanco',
#        'Cotoneaster', 'Fenix', 'Libocedro (Calocedro)', 'Callistemon',
# ...

# %%
len(df['nombre_com'].unique())
# Out:
# 337

# %%
cant_ejemplares = df['nombre_com'].value_counts()
cant_ejemplares.head(10)
# Out:
# nombre_com
# Eucalipto               4112
# Tipa blanca             4031
# Jacarandá               3255
# Palo borracho rosado    3150
# Casuarina               2719
# Fresno americano        2166
# Plátano                 1556
# Ciprés                  1467
# Ceibo                   1149
# Pindó                   1068
# Name: count, dtype: int64

# %%
df_ombues = df[df['nombre_com'] == 'Ombú']
df_ombues.head()
# Out:
#            long        lat  id_arbol  altura_tot  diametro  inclinacio  \
# 3    -58.478129 -34.644567         4          17        50           0
# 4    -58.478121 -34.644598         5          17        50           0
# 5    -58.478103 -34.644641         6          17        50           0
# 6    -58.478095 -34.644677         7          17        50           0
# 2344 -58.397727 -34.599373      2345           8        36           0
#
#       id_especie nombre_com         nombre_cie                     tipo_folla  \
# 3             65       Ombú  Phytolacca dioica  Árbol Latifoliado Caducifolio
# 4             65       Ombú  Phytolacca dioica  Árbol Latifoliado Caducifolio
# 5             65       Ombú  Phytolacca dioica  Árbol Latifoliado Caducifolio
# 6             65       Ombú  Phytolacca dioica  Árbol Latifoliado Caducifolio
# 2344          65       Ombú  Phytolacca dioica  Árbol Latifoliado Caducifolio
#
#                       espacio_ve  \
# ...

# %%
# redefinir indices originales
df_ombues = df_ombues.reset_index()
df_ombues.head()
# Out:
#    index       long        lat  id_arbol  altura_tot  diametro  inclinacio  \
# 0      3 -58.478129 -34.644567         4          17        50           0
# 1      4 -58.478121 -34.644598         5          17        50           0
# 2      5 -58.478103 -34.644641         6          17        50           0
# 3      6 -58.478095 -34.644677         7          17        50           0
# 4   2344 -58.397727 -34.599373      2345           8        36           0
#
#    id_especie nombre_com         nombre_cie                     tipo_folla  \
# 0          65       Ombú  Phytolacca dioica  Árbol Latifoliado Caducifolio
# 1          65       Ombú  Phytolacca dioica  Árbol Latifoliado Caducifolio
# 2          65       Ombú  Phytolacca dioica  Árbol Latifoliado Caducifolio
# 3          65       Ombú  Phytolacca dioica  Árbol Latifoliado Caducifolio
# 4          65       Ombú  Phytolacca dioica  Árbol Latifoliado Caducifolio
#
#                    espacio_ve  \
# ...

# %%
# selección de columnas
cols = ['nombre_com', 'altura_tot', 'diametro', 'inclinacio']
df_ombues = df_ombues[cols]
df_ombues.head()
# Out:
#   nombre_com  altura_tot  diametro  inclinacio
# 0       Ombú          17        50           0
# 1       Ombú          17        50           0
# 2       Ombú          17        50           0
# 3       Ombú          17        50           0
# 4       Ombú           8        36           0

# %%
# consulta
df_ombues = df[(df['nombre_com'] == 'Ombú') & (df['altura_tot'] > 10)][cols]
df_ombues.head()
# Out:
#      nombre_com  altura_tot  diametro  inclinacio
# 3          Ombú          17        50           0
# 4          Ombú          17        50           0
# 5          Ombú          17        50           0
# 6          Ombú          17        50           0
# 2485       Ombú          15       140           0

# %% [markdown]
# ### Acceso y selección de datos por índice o posición

# %%
# acceso por índice
df.loc[127]
# Out:
# long                                                 -58.465575
# lat                                                  -34.666648
# id_arbol                                                    128
# altura_tot                                                   12
# diametro                                                     15
# inclinacio                                                    0
# id_especie                                                  214
# nombre_com                               Álamo negro del Canada
# nombre_cie                                 Populus x canadensis
# tipo_folla                        Árbol Latifoliado Caducifolio
# espacio_ve                                        INDOAMERICANO
# ubicacion     LACARRA, Av. - ESCALADA, Av. - CASTAÑARES, Av....
# nombre_fam                                           Salicáceas
# nombre_gen                                              Populus
# origen                                                  Exótico
# ...

# %%
# acceso por número de posición
df.iloc[127]
# Out:
# long                                                 -58.465575
# lat                                                  -34.666648
# id_arbol                                                    128
# altura_tot                                                   12
# diametro                                                     15
# inclinacio                                                    0
# id_especie                                                  214
# nombre_com                               Álamo negro del Canada
# nombre_cie                                 Populus x canadensis
# tipo_folla                        Árbol Latifoliado Caducifolio
# espacio_ve                                        INDOAMERICANO
# ubicacion     LACARRA, Av. - ESCALADA, Av. - CASTAÑARES, Av....
# nombre_fam                                           Salicáceas
# nombre_gen                                              Populus
# origen                                                  Exótico
# ...

# %% [markdown]
# ### Máximos y mínimos

# %%
df['altura_tot'].max()
# Out:
# 54

# %%
df['altura_tot'].min()
# Out:
# 0

# %% [markdown]
# ### Plots

# %% [markdown]
# * Pandas permite hacer plots de manera nativa (internamente usa seaborn)
# * Hacer gráficos facilita la exploración de los datos

# %%
# gráfico de dispersión
df_ombues.plot.scatter(x = 'diametro', y = 'altura_tot')
# Out:
# <Axes: xlabel='diametro', ylabel='altura_tot'>

# %%
# histograma
df_ombues.altura_tot.plot.hist(bins = 25, figsize=(4, 4))
# Out:
# <Axes: ylabel='Frequency'>
